# %% [markdown]
# # Before you start :
#    - These exercises are related to the Pivot table and correlation lessons.
#    - Keep in mind that you need to use some of the functions you learned in the previous lessons.
#    - All datasets are provided in the `your-code` folder of this lab.
#    - Elaborate your codes and outputs as much as you can.
#    - Try your best to answer the questions and complete the tasks and most importantly enjoy the process!!!

# %% [markdown]
# #### Import all the libraries that are necessary.

# %%
import pandas as pd
import statistics as stats
import numpy as np
import math
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# #### Open the ` Employee.csv` file and name your dataset `employee`.

# %%
employee = pd.read_csv('data/Employee.csv')
employee.head(20)
# Out:
#      Name Department Education Gender      Title  Years  Salary
# 0    Jose         IT  Bachelor      M    analyst      1      35
# 1   Maria         IT    Master      F    analyst      2      30
# 2   David         HR    Master      M    analyst      2      30
# 3   Sonia         HR  Bachelor      F    analyst      4      35
# 4  Samuel      Sales    Master      M  associate      3      55
# 5     Eva      Sales  Bachelor      F  associate      2      55
# 6  Carlos         IT    Master      M         VP      8      70
# 7   Pedro         IT       Phd      M  associate      7      60
# 8     Ana         HR    Master      F         VP      8      70

# %% [markdown]
# #### What's the mean salary by department?
# Hint : There are 2 ways to do it - one way is with groupby and the other way is with pivot tables. Do it both ways.

# %%
# Method 1
employee.groupby(['Department']).agg({'Salary': np.mean})
# Out:
#             Salary
# Department
# HR           45.00
# IT           48.75
# Sales        55.00

# %%
employee.pivot_table(index= ['Department'], values = ['Salary'], aggfunc = {'Salary':'mean'})
# Out:
#             Salary
# Department
# HR           45.00
# IT           48.75
# Sales        55.00

# %% [markdown]
# #### We want now to group the data by more than one column. Use Pandas pivot table function to select the mean salary by department and title.

# %%
# Method 2
employee.pivot_table(index= ['Department', 'Title'], values = ['Salary'], aggfunc = {'Salary':'mean'}).reset_index()
# Out:
#   Department      Title  Salary
# 0         HR         VP    70.0
# 1         HR    analyst    32.5
# 2         IT         VP    70.0
# 3         IT    analyst    32.5
# 4         IT  associate    60.0
# 5      Sales  associate    55.0

# %%
employee.groupby(['Title','Department']).agg({'Salary': np.mean}).reset_index()
# Out:
#        Title Department  Salary
# 0         VP         HR    70.0
# 1         VP         IT    70.0
# 2    analyst         HR    32.5
# 3    analyst         IT    32.5
# 4  associate         IT    60.0
# 5  associate      Sales    55.0

# %% [markdown]
# #### We want to display the number of years of work experience and the salary for each Title. Add Years as a column in your pivot table.
# *Hint: Use Pandas doc(see References in README.md) to explore the pivot_table() arguments*

# %%
employee.pivot_table(index= ['Title'], values = ['Salary', 'Years'])
# Out:
#               Salary  Years
# Title
# VP         70.000000   8.00
# analyst    32.500000   2.25
# associate  56.666667   4.00

# %% [markdown]
# #### We want to know the information about the mean salary and number of employees in each department and for each job title.

# %%
employee.pivot_table(index=['Department','Title'], values = ['Salary', 'Name'], margins=True, margins_name='Count', aggfunc= {'Name':'count','Salary' :'mean', }).reset_index()
# Out:
#   Department      Title  Name     Salary
# 0         HR         VP     1  70.000000
# 1         HR    analyst     2  32.500000
# 2         IT         VP     1  70.000000
# 3         IT    analyst     2  32.500000
# 4         IT  associate     1  60.000000
# 5      Sales  associate     2  55.000000
# 6      Count                9  48.888889

# %% [markdown]
# #### We want to know for each department and for each job title the Salary's median, minimum, maximum and standard deviation. Comment your results.

# %%
employee.pivot_table(index= ['Department','Title',], values = ['Salary'], aggfunc = {'median','min','max','std'}).reset_index()
#This operation results in Nans for the standard deviation, 
#because there's only one associate in IT, one VP in IT and one VP in HR, 
#while the 2 associates in Sales earn the same salary (std =0).
# Out:
#   Department      Title Salary
#                            max median   min       std
# 0         HR         VP   70.0   70.0  70.0       NaN
# 1         HR    analyst   35.0   32.5  30.0  3.535534
# 2         IT         VP   70.0   70.0  70.0       NaN
# 3         IT    analyst   35.0   32.5  30.0  3.535534
# 4         IT  associate   60.0   60.0  60.0       NaN
# 5      Sales  associate   55.0   55.0  55.0  0.000000

# %% [markdown]
# #### Based on your comments, fill the missing values with an appropriate value.

# %%
employee.pivot_table(index= ['Department','Title',], values = ['Salary'], aggfunc = {'median','min','max','std'}).reset_index().fillna(0)
# Out:
#   Department      Title Salary
#                            max median   min       std
# 0         HR         VP   70.0   70.0  70.0  0.000000
# 1         HR    analyst   35.0   32.5  30.0  3.535534
# 2         IT         VP   70.0   70.0  70.0  0.000000
# 3         IT    analyst   35.0   32.5  30.0  3.535534
# 4         IT  associate   60.0   60.0  60.0  0.000000
# 5      Sales  associate   55.0   55.0  55.0  0.000000

# %% [markdown]
# #### The stake holders want to know for each department the number of employees and how much money is spend on salaries. Could you provide that information?

# %%
employee.pivot_table(index=['Department'], values = ['Salary', 'Name'], margins=True, margins_name='Count', aggfunc= {'Salary' :'sum', 'Name':'count'})
# Out:
#             Name  Salary
# Department
# HR             3     135
# IT             4     195
# Sales          2     110
# Count          9     440

# %% [markdown]
# #### For each Department and Title, we want to know the the total years of work experience and the mean salary.

# %%
employee.pivot_table(index=['Department'], values = ['Salary','Years'], columns=['Title'], margins=True, margins_name='Salary-mean/Years-Total', aggfunc={'Years':np.sum,'Salary':np.mean}).fillna('').round(2)
# Out:
#                         Salary                                             \
# Title                       VP analyst  associate Salary-mean/Years-Total
# Department
# HR                        70.0    32.5                              45.00
# IT                        70.0    32.5       60.0                   48.75
# Sales                                        55.0                   55.00
# Salary-mean/Years-Total   70.0    32.5  56.666667                   48.89
#
#                         Years
# Title                      VP analyst associate Salary-mean/Years-Total
# Department
# HR                        8.0     6.0                                14
# IT                        8.0     3.0       7.0                      18
# Sales                                       5.0                       5
# Salary-mean/Years-Total  16.0     9.0      12.0                      37

# %%
employee.pivot_table(index= ['Department', 'Title'], values = ['Salary','Years'], aggfunc = {'Salary':'mean','Years':'sum'}).reset_index()
# Out:
#   Department      Title  Salary  Years
# 0         HR         VP    70.0      8
# 1         HR    analyst    32.5      6
# 2         IT         VP    70.0      8
# 3         IT    analyst    32.5      3
# 4         IT  associate    60.0      7
# 5      Sales  associate    55.0      5

# %%
#employee.pivot_table(index=['Department','Title'], values = ['Salary', 'Years'], margins=True, margins_name='Count', aggfunc= {'Salary' :'mean', 'Name':'count'})
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7380/2319884440.py in <module>
# ----> 1 employee.pivot_table(index=['Department','Title'], values = ['Salary', 'Years'], margins=True, margins_name='Count', aggfunc= {'Salary' :'mean', 'Name':'count'})
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in pivot_table(self, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#    7949         from pandas.core.reshape.pivot import pivot_table
#    7950
# -> 7951         return pivot_table(
#    7952             self,
#    7953             values=values,
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\pivot.py in pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#      93         return table.__finalize__(data, method="pivot_table")
#      94
# ...

# %% [markdown]
# ### Bonus
#
# #### We now want to compute the mean salary after removing the maxima for each Department. Create the appropriate pivot table.
#
# Hint: Write a custom function.

# %%
def without_max(employee):
     
    max_sal_dp = employee['Department','Salary'].max()
    department = employee['Department']
    
    for i in department:
        if x > max_sal_dp:
            return x
        else:
            return 0

employeewithoutmax = employee.apply(without_max)
employeewithoutmax.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7380/1227274331.py in <module>
#      10             return 0
#      11
# ---> 12 employeewithoutmax = employee.apply(without_max)
#      13 employeewithoutmax.head()
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in apply(self, func, axis, raw, result_type, args, **kwargs)
#    8738             kwargs=kwargs,
#    8739         )
# -> 8740         return op.apply()
#    8741
#    8742     def applymap(
#
# ~\anaconda3\lib\site-packages\pandas\core\apply.py in apply(self)
#     686             return self.apply_raw()
#     687
# --> 688         return self.apply_standard()
#     689
#     690     def agg(self):
#
# ~\anaconda3\lib\site-packages\pandas\core\apply.py in apply_standard(self)
#     810
#     811     def apply_standard(self):
# ...

# %%
employee.pivot_table(index= ['Department'], values = ['Salary'], aggfunc = {'Salary':'max'})
# Out:
#             Salary
# Department
# HR              70
# IT              70
# Sales           55

# %%
#employee2 = (employee.pivot_table(index= ['Department'], values = ['Salary'], aggfunc = {'Salary':'max'})).to_list()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7380/731367955.py in <module>
# ----> 1 employee2 = (employee.pivot_table(index= ['Department'], values = ['Salary'], aggfunc = {'Salary':'max'})).to_list()
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'to_list'
